# %% [markdown]
# # Parsing a HTML Page for URLs using Beautiful Soup 4
#
# This notebook's aim is to extract and format hyperlinks from a URL into a csv formatted file. This will cover how to read a URL, use Beautiful Soup 4 and Python 3 to extract the hyperlinks, and finally save them in a csv formatted file.
#
# ## Libraries and Resources used
#
# -  Python 3
# -  Beautiful Soup 4
# -  Request (A simple HTTP library for Python)
#
# ## Note:
#
# For installation of the nessesary resources and libraries refer to their respective home page for installation steps for your operation system.
#
# In this tutorial we will be taking hyperlinks from Wikipedia. It is possilbe when you are viewing this tutorial, there have been changes done to the example URLs in question. If that is true, this may result in your own implementation of this code to produce different results or throwing an error.

# %% [markdown]
# ### Importing the requried libaries

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Loading the desired URL
#
# In this example we are going to use a wikipedia page about the Mid-Autumn Festival.

# %%
#Using request we can fetch the URL we want
webPage = requests.get('https://en.wikipedia.org/wiki/Mid-Autumn_Festival#Mooncakes')

# %% [markdown]
# ### Creating a Beauitful Soup Object
#
# A Beauitful Soup object is a special type of object that allows us to perform a varitity of different operations. But in this tutorial we will not be using all the functionality built into the library.

# %%
# Here we create a soup object using the text from the webPage we declared eariler
#'html.parser' is used to tell the library that we are parsing a HTML
soup = BeautifulSoup(webPage.text, 'html.parser')

# %% [markdown]
# ### Finding all the 'a' or 'anchor' Tags
#
# Now that we have the web page loaded it is time to get all the URLs. To do this we look for the 'a' Tags or the 'anchor' Tags. These contain the URLs we are looking for.

# %%
# Here we declare we ask Beautiful Soup to find all the 'a' Tags in the webpage
anchor_on_page = soup.find_all('a')

# %% [markdown]
# ### Storing the values we want
#
# Before we can look at gathering all the URLs we first need to save it somewhere (so later on we have a more organized dataset to work off of)

# %%
# Create a dictionary with information about each link
linkDictionary = {}

# %% [markdown]
# ### Gathering the URLs
#
# Now we are going to examine each 'a' or 'anchor' tag for the keyword 'href'. In HTML this is use to denote a link to another webpage. Therefore we can skip any tags that don't have this key word and save the ones who do have it into the dictionary.

# %%
# Iterate through each anchor in our list of anchor
for element in anchor_on_page:
    
    # If the element does not have the keyword we are looking for we are going to skip it
    if element.get('href') == None:
        continue
    
    # Create another nested dictionary for each link under "href". 
    # The nested dictionary is used to store another other meta data/ information that is also inside the anchor
    linkDictionary[element.get('href')] = {}
    
    # In the entry for the nested dictionary we are going to assign the keyword "link" with the URL link
    linkDictionary[element.get('href')]['link'] = str(element.get('href'))
    
    # Grab any string attached to the anchor. Setting all that have none present to 'null'
    if (element.string == None):
        linkDictionary[element.get('href')]['string'] = 'null'
    else:
        linkDictionary[element.get('href')]['string'] = element.string
    
    # This next part is dependant on the url you are using. In this example, the Wikipedia page sometimes uses the 
    # word "title" inside their anchor. Therefore in the cases that it does appear I want to save it, if it doesn't
    # exist then I want to enter "null" for the value. 
    if (element.get('title')) == None:
        linkDictionary[element.get('href')]['title'] = 'null'
    else:
        linkDictionary[element.get('href')]['title'] = element.get('title')

# %% [markdown]
# One of the main reasons we don't skip inserting the information of 'title' or 'string' into the dictionary when there isn't one is because we want our csv to be consistence. That each entry will have something in each field, even if it is empty.
#
# Depending on the website you are trying to scrap, other meta data other than 'title'. There could be many more or none at all. It is up to you the extent of information you want to record. To check to see what type of other meta data are embedded inspect the source code of the website.

# %% [markdown]
# ### Testing checkpoint
#
# Now before we move onto formatting the newly aquired information we are going to see what linkDictionary looks like

# %%
#For each key and value inside the dictionary we print out the result
for key, value in linkDictionary.items():
    print("Key: " + str(key) + "\n Value: " + str(value) + "\n")
# Out:
# Key: http://www.nytimes.com/content/help/site/ie9-support.html
#  Value: {'link': 'http://www.nytimes.com/content/help/site/ie9-support.html', 'string': 'LEARN MORE »'}
#
# Key: #top-news
#  Value: {'link': '#top-news', 'string': 'Skip to content'}
#
# Key: #site-index-navigation
#  Value: {'link': '#site-index-navigation', 'string': 'Skip to navigation'}
#
# Key: http://cn.nytimes.com
#  Value: {'link': 'http://cn.nytimes.com', 'string': '中文 (Chinese)'}
#
# Key: https://www.nytimes.com/es/
#  Value: {'link': 'https://www.nytimes.com/es/', 'string': 'Español'}
#
# Key: https://www.nytimes.com/
#  Value: {'link': 'https://www.nytimes.com/', 'string': 'null'}
#
# Key: http://www.nytimes.com/pages/todayspaper/index.html
#  Value: {'link': 'http://www.nytimes.com/pages/todayspaper/index.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/video
#  Value: {'link': 'https://www.nytimes.com/video', 'string': 'Video'}
#
# Key: https://www.nytimes.com/section/world
#  Value: {'link': 'https://www.nytimes.com/section/world', 'string': 'World'}
#
# Key: https://www.nytimes.com/section/us
#  Value: {'link': 'https://www.nytimes.com/section/us', 'string': 'U.S.'}
#
# Key: https://www.nytimes.com/section/politics
#  Value: {'link': 'https://www.nytimes.com/section/politics', 'string': 'Politics'}
#
# Key: https://www.nytimes.com/section/nyregion
#  Value: {'link': 'https://www.nytimes.com/section/nyregion', 'string': 'N.Y.'}
#
# Key: https://www.nytimes.com/section/business
#  Value: {'link': 'https://www.nytimes.com/section/business', 'string': 'Business'}
#
# Key: https://www.nytimes.com/section/opinion
#  Value: {'link': 'https://www.nytimes.com/section/opinion', 'string': 'Opinion'}
#
# Key: https://www.nytimes.com/section/technology
#  Value: {'link': 'https://www.nytimes.com/section/technology', 'string': 'Tech'}
#
# Key: https://www.nytimes.com/section/science
#  Value: {'link': 'https://www.nytimes.com/section/science', 'string': 'Science'}
#
# Key: https://www.nytimes.com/section/health
#  Value: {'link': 'https://www.nytimes.com/section/health', 'string': 'Health'}
#
# Key: https://www.nytimes.com/section/sports
#  Value: {'link': 'https://www.nytimes.com/section/sports', 'string': 'Sports'}
#
# Key: https://www.nytimes.com/section/arts
#  Value: {'link': 'https://www.nytimes.com/section/arts', 'string': "Today's Arts"}
#
# Key: https://www.nytimes.com/section/fashion
#  Value: {'link': 'https://www.nytimes.com/section/fashion', 'string': 'Fashion & Style'}
#
# Key: https://www.nytimes.com/pages/dining/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/dining/index.html', 'string': 'Food'}
#
# Key: https://www.nytimes.com/section/travel
#  Value: {'link': 'https://www.nytimes.com/section/travel', 'string': 'Travel'}
html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/opinion/trump-puerto-rico.html', 'string': 'Rosenthal: Trump’s Latest Outrage Against Puerto Rico'}
#
# Key: https://www.nytimes.com/2017/10/11/opinion/weinstein-sexual-harassment-enablers.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/opinion/weinstein-sexual-harassment-enablers.html', 'string': 'Stephens: Weinstein Enablers'}
#
# Key: https://www.nytimes.com/2017/10/12/opinion/texas-robert-pruett-execution.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/opinion/texas-robert-pruett-execution.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/11/opinion/trump-korea-war-competence.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/opinion/trump-korea-war-competence.html', 'string': '\n            Editorial: Mr. Trump Alone Can Order a Nuclear Strike. Congress Can Change That.        '}
#
# Key: https://www.nytimes.com/2017/10/12/opinion/democrats-are-playing-checkers-while-trump-is-playing-chess.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/opinion/democrats-are-playing-checkers-while-trump-is-playing-chess.html', 'string': 'Edsall: Democrats Play Checkers, Trump Plays Chess'}
#
# Key: https://www.nytimes.com/2017/10/11/opinion/contraception-religious-exemption.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/opinion/contraception-religious-exemption.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/11/opinion/america-forgotten-virgin-islands.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/opinion/america-forgotten-virgin-islands.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/12/opinion/israel-congress-bds.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/opinion/israel-congress-bds.html', 'string': 'Congress’s Un-American, Bad-for-Israel Agenda'}
#
# Key: https://www.nytimes.com/2017/10/12/opinion/book-publishing-amazon-sales.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/opinion/book-publishing-amazon-sales.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/12/opinion/ben-shapiro.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/opinion/ben-shapiro.html', 'string': 'Ben Shapiro’s Hollow Bravery'}
#
# Key: https://www.nytimes.com/2017/10/11/opinion/what-makes-eminems-anti-trump-rap-different.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/opinion/what-makes-eminems-anti-trump-rap-different.html', 'string': 'What Makes Eminem’s Anti-Trump Rap Different'}
#
# Key: https://www.nytimes.com/2017/10/12/opinion/helping-puerto-rico-recover.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/opinion/helping-puerto-rico-recover.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/11/reader-center/new-york-times-recipe-commenters-politely-spill-their-guts.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/reader-center/new-york-times-recipe-commenters-politely-spill-their-guts.html', 'string': '\n            Times Insider: New York Times Recipe Commenters (Politely) Spill Their Guts        '}
#
# Key: https://www.nytimes.com/2017/10/11/insider/smelly-and-dirty-and-in-bombing-trial-suddenly-a-star.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/insider/smelly-and-dirty-and-in-bombing-trial-suddenly-a-star.html', 'string': '\n            Smelly and Dirty and, in Bombing Trial, Suddenly a Star        '}
#
# Key: https://www.nytimes.com/section/insider
#  Value: {'link': 'https://www.nytimes.com/section/insider', 'string': 'Times Insider »'}
#
# Key: https://www.nytimes.com/crosswords
#  Value: {'link': 'https://www.nytimes.com/crosswords', 'string': 'Crossword'}
#
# Key: http://wordplay.blogs.nytimes.com
#  Value: {'link': 'http://wordplay.blogs.nytimes.com', 'string': 'Wordplay »'}
#
# Key: https://www.nytimes.com/video?src=vidm
#  Value: {'link': 'https://www.nytimes.com/video?src=vidm', 'string': ' explore all videos »'}
#
# Key: https://www.nytimes.com/section/arts/television
#  Value: {'link': 'https://www.nytimes.com/section/arts/television', 'string': 'Television'}
#
# Key: https://www.nytimes.com/2017/10/12/arts/television/dynasty-dallas-reboot.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/arts/television/dynasty-dallas-reboot.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/pages/opinion/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/opinion/index.html', 'string': "Today's Opinion"}
#
# Key: https://www.nytimes.com/2017/10/12/opinion/learning-disabilities-attention-deficit.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/opinion/learning-disabilities-attention-deficit.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/11/science/pumas-solitary-social.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/science/pumas-solitary-social.html', 'string': '\n            Trilobites: Solitary Pumas Turn Out to Be Mountain Lions Who Lunch        '}
#
# Key: https://cooking.nytimes.com/68861692-nyt-cooking/807163-our-greatest-pizza-recipes
#  Value: {'link': 'https://cooking.nytimes.com/68861692-nyt-cooking/807163-our-greatest-pizza-recipes', 'string': 'null'}
#
# Key: https://www.nytimes.com/section/well/mind
#  Value: {'link': 'https://www.nytimes.com/section/well/mind', 'string': 'Mind'}
#
# Key: https://www.nytimes.com/2017/10/11/well/mind/high-blood-pressure-in-midlife-tied-to-later-dementia.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/well/mind/high-blood-pressure-in-midlife-tied-to-later-dementia.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/11/travel/how-martha-stewart-travels.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/travel/how-martha-stewart-travels.html', 'string': '\n            Carry-On: What Martha Stewart Can’t Travel Without        '}
#
# Key: https://www.nytimes.com/section/well/live
#  Value: {'link': 'https://www.nytimes.com/section/well/live', 'string': 'Live'}
#
# Key: https://www.nytimes.com/2017/10/05/well/live/bleeding-first-aid.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/05/well/live/bleeding-first-aid.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/12/arts/television/netflix-mindhunter-review.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/arts/television/netflix-mindhunter-review.html', 'string': '\n            Review: Netflix’s ‘Mindhunter’ Is More Chatter Than Splatter        '}
#
# Key: https://www.nytimes.com/2017/10/11/nyregion/college-websites-disabled.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/nyregion/college-websites-disabled.html', 'string': '\n            College Websites Must Accommodate Disabled Students, Lawsuits Say        '}
#
# Key: https://www.nytimes.com/pages/world/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/world/index.html', 'string': 'World »'}
#
# Key: https://www.nytimes.com/2017/10/12/world/africa/east-africa-rwanda-used-clothing.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/world/africa/east-africa-rwanda-used-clothing.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/12/business/china-richest-billionaires.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/business/china-richest-billionaires.html', 'string': '\n            Tech and Real Estate Lift the Fortunes of China’s Richest        '}
#
# Key: https://www.nytimes.com/pages/business/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/business/index.html', 'string': 'Business Day »'}
#
# Key: https://www.nytimes.com/2017/10/12/technology/sheryl-sandberg-facebook-ads.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/technology/sheryl-sandberg-facebook-ads.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/12/business/kobe-steel-japan-trains.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/business/kobe-steel-japan-trains.html', 'string': '\n            Kobe Steel Problems May Be More Widespread, Raising Fears on High-Speed Rail        '}
#
# Key: https://www.nytimes.com/pages/technology/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/technology/index.html', 'string': 'Technology »'}
#
# Key: https://www.nytimes.com/2017/10/11/technology/the-frightful-five-want-to-rule-entertainment-they-are-hitting-limits.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/technology/the-frightful-five-want-to-rule-entertainment-they-are-hitting-limits.html', 'string': '\n            State of the Art: The Frightful Five Want to Rule Entertainment. They Are Hitting Limits.        '}
#
# Key: https://www.nytimes.com/2017/10/11/technology/facebook-election.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/technology/facebook-election.html', 'string': '\n            The Shift: We Asked Facebook 12 Questions About the Election, and Got 5 Answers        '}
#
# Key: https://www.nytimes.com/pages/arts/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/arts/index.html', 'string': 'Arts »'}
#
# Key: https://www.nytimes.com/2017/10/11/movies/harvey-weinstein-hollywood.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/movies/harvey-weinstein-hollywood.html', 'string': '\n            Critic’s Notebook: Harvey Weinstein Is Gone. But Hollywood Still Has a Problem.        '}
#
# Key: https://www.nytimes.com/2017/10/12/arts/rose-mcgowan-twitter-weinstein.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/arts/rose-mcgowan-twitter-weinstein.html', 'string': '\n            Rose McGowan’s Twitter Account Locked After Posts About Weinstein        '}
#
# Key: https://www.nytimes.com/pages/politics/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/politics/index.html', 'string': 'Politics »'}
#
# Key: https://www.nytimes.com/2017/10/12/fashion/fashion-industry-gossip-addiction-paris-fashion-week.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/fashion/fashion-industry-gossip-addiction-paris-fashion-week.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/11/style/tom-hanks-uncommon-type-harvey-weinstein-donald-trump.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/style/tom-hanks-uncommon-type-harvey-weinstein-donald-trump.html', 'string': '\n            With...Tom Hanks: Hollywood’s Most Decent Fella on Weinstein, Trump and History        '}
#
# Key: https://www.nytimes.com/2017/10/12/style/what-happens-when-a-will-is-unsigned.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/style/what-happens-when-a-will-is-unsigned.html', 'string': '\n            Social Q’s: What Happens When a Will is Unsigned? (It’s Not Fun)        '}
#
# Key: https://www.nytimes.com/section/movies
#  Value: {'link': 'https://www.nytimes.com/section/movies', 'string': 'Movies'}
#
# Key: https://www.nytimes.com/2017/10/12/movies/ranking-studio-ghibli-movies.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/movies/ranking-studio-ghibli-movies.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/11/nyregion/cy-vance-defends-weinstein-decision.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/nyregion/cy-vance-defends-weinstein-decision.html', 'string': '\n            Cy Vance Defends Decision Not to Pursue Case Against Harvey Weinstein        '}
#
# Key: https://www.nytimes.com/pages/sports/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/sports/index.html', 'string': 'Sports »'}
#
# Key: https://www.nytimes.com/2017/10/12/sports/nfl-predictions-schedule.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12
html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/travel/japan-monastery-koyasan.html', 'string': '\n            Personal Journeys: Seeking Solitude in Japan’s Mountain Monasteries        '}
#
# Key: https://www.nytimes.com/section/books
#  Value: {'link': 'https://www.nytimes.com/section/books', 'string': 'Books'}
#
# Key: https://www.nytimes.com/2017/10/12/books/review-travels-with-myself-and-another-martha-gellhorn.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/books/review-travels-with-myself-and-another-martha-gellhorn.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/10/books/review-grant-biography-ron-chernow.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/10/books/review-grant-biography-ron-chernow.html', 'string': '\n            Books of The Times: In Ron Chernow’s ‘Grant,’ an American Giant’s Makeover Continues        '}
#
# Key: https://www.nytimes.com/section/education
#  Value: {'link': 'https://www.nytimes.com/section/education', 'string': 'Education'}
#
# Key: https://www.nytimes.com/2017/10/10/opinion/college-social-media-hate.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/10/opinion/college-social-media-hate.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/video/education/100000005108366/classroom-waldorf-montessori-public.html
#  Value: {'link': 'https://www.nytimes.com/video/education/100000005108366/classroom-waldorf-montessori-public.html', 'string': '\n            Which Classroom Setting Suits You?        '}
#
# Key: https://www.nytimes.com/2017/09/29/your-money/paying-for-college/payback-college-loans.html
#  Value: {'link': 'https://www.nytimes.com/2017/09/29/your-money/paying-for-college/payback-college-loans.html', 'string': '\n            Your Money: A Game to Help Students Pay the Right Price for College        '}
#
# Key: https://www.nytimes.com/2017/10/12/dining/drinks/five-common-wine-myths-debunked.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/dining/drinks/five-common-wine-myths-debunked.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/12/dining/ethiopian-food-benyam-review-harlem.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/dining/ethiopian-food-benyam-review-harlem.html', 'string': '\n            Hungry City: Traditional Ethiopian Food in a Cosmopolitan Setting        '}
#
# Key: https://www.nytimes.com/2017/10/09/dining/mike-isabella-washington-dc-restaurateur.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/09/dining/mike-isabella-washington-dc-restaurateur.html', 'string': '\n            Mike Isabella, Washington’s Restless Restaurateur        '}
#
# Key: https://www.nytimes.com/2017/10/12/magazine/in-northern-minnesota-two-economies-square-off-mining-vs-wilderness.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/magazine/in-northern-minnesota-two-economies-square-off-mining-vs-wilderness.html', 'string': '\n            Feature: In Northern Minnesota, Two Economies Square Off: Mining vs. Wilderness        '}
#
# Key: https://www.nytimes.com/2017/10/12/magazine/letter-of-recommendation-dunking.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/magazine/letter-of-recommendation-dunking.html', 'string': '\n            Letter of Recommendation: Letter of Recommendation: Dunking        '}
#
# Key: https://www.nytimes.com/pages/realestate/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/realestate/index.html', 'string': 'Real Estate »'}
#
# Key: https://www.nytimes.com/2017/10/12/realestate/seeking-the-peace-of-westchester.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/realestate/seeking-the-peace-of-westchester.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/12/realestate/homes-for-sale-in-new-york-and-connecticut.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/realestate/homes-for-sale-in-new-york-and-connecticut.html', 'string': '\n            On the Market: Homes for Sale in New York and Connecticut        '}
#
# Key: https://www.nytimes.com/2017/10/12/realestate/homes-for-sale-in-midtown-east-the-upper-east-side-and-carroll-gardens-brooklyn.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/realestate/homes-for-sale-in-midtown-east-the-upper-east-side-and-carroll-gardens-brooklyn.html', 'string': '\n            On the Market: Homes for Sale in New York City        '}
#
# Key: https://www.nytimes.com/section/upshot
#  Value: {'link': 'https://www.nytimes.com/section/upshot', 'string': 'The Upshot »'}
#
# Key: https://www.nytimes.com/interactive/2017/10/12/upshot/a-bump-stock-ban-is-popular-but-experts-have-their-doubts.html
#  Value: {'link': 'https://www.nytimes.com/interactive/2017/10/12/upshot/a-bump-stock-ban-is-popular-but-experts-have-their-doubts.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/interactive/2017/10/11/upshot/trump-nfl-polarization.html
#  Value: {'link': 'https://www.nytimes.com/interactive/2017/10/11/upshot/trump-nfl-polarization.html', 'string': '\n            The N.F.L. Is Now One of the Most Divisive Brands in the U.S.        '}
#
# Key: https://www.nytimes.com/2017/10/11/upshot/the-word-may-be-toxic-but-amnesty-is-everywhere.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/upshot/the-word-may-be-toxic-but-amnesty-is-everywhere.html', 'string': '\n            Quality of Mercy: The Word May Be Toxic, but Amnesty Is Everywhere        '}
#
# Key: https://www.nytimes.com/2017/10/11/insider/tech-column-dread.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/11/insider/tech-column-dread.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/pages/automobiles/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/automobiles/index.html', 'string': 'Automobiles »'}
#
# Key: https://www.nytimes.com/2017/10/05/automobiles/wheels/electric-cars-charging.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/05/automobiles/wheels/electric-cars-charging.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/10/business/kobe-steel-japan.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/10/business/kobe-steel-japan.html', 'string': '\n            Kobe Steel’s Falsified Data Is Another Blow to Japan’s Reputation        '}
#
# Key: https://www.nytimes.com/2017/10/12/t-magazine/design/betony-vernon-paris-apartment.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/t-magazine/design/betony-vernon-paris-apartment.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/12/t-magazine/fashion/dresses-over-pants.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/t-magazine/fashion/dresses-over-pants.html', 'string': '\n            Slinky Dresses, Meet Slouchy Trousers        '}
#
# Key: https://www.nytimes.com/2017/10/12/t-magazine/gloria-vanderbilt-illustrated-interview.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/t-magazine/gloria-vanderbilt-illustrated-interview.html', 'string': '\n            The Illustrated Interview: Gloria Vanderbilt        '}
#
# Key: https://www.nytimes.com/2017/10/12/realestate/international-rents-per-square-foot.html
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/realestate/international-rents-per-square-foot.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/2017/10/12/realestate/international-rents-per-square-foot.html?hp&target=comments#commentsContainer
#  Value: {'link': 'https://www.nytimes.com/2017/10/12/realestate/international-rents-per-square-foot.html?hp&target=comments#commentsContainer', 'string': 'null'}
#
# Key: http://www.nytimes.com/real-estate/find-a-home
#  Value: {'link': 'http://www.nytimes.com/real-estate/find-a-home', 'string': 'Search for Homes for Sale or Rent'}
#
# Key: https://www.nytimes.com/real-estate/mortgage-calculator
#  Value: {'link': 'https://www.nytimes.com/real-estate/mortgage-calculator', 'string': 'Mortgage Calculator'}
#
# Key: https://www.nytimes.com/trending/
#  Value: {'link': 'https://www.nytimes.com/trending/', 'string': 'Most Emailed'}
#
# Key: https://www.nytimes.com/gst/mostpopular.html
#  Value: {'link': 'https://www.nytimes.com/gst/mostpopular.html', 'string': 'Most Viewed'}
#
# Key: http://www.nytimes.com/trending/
#  Value: {'link': 'http://www.nytimes.com/trending/', 'string': 'Trending'}
#
# Key: https://www.nytimes.com/recommendations
#  Value: {'link': 'https://www.nytimes.com/recommendations', 'string': 'Recommended for you'}
#
# Key: https://www.nytimes.com/pages/todayspaper/index.html
#  Value: {'link': 'https://www.nytimes.com/pages/todayspaper/index.html', 'string': "Today's Paper"}
#
# Key: https://www.nytimes.com/section/corrections
#  Value: {'link': 'https://www.nytimes.com/section/corrections', 'string': 'Corrections'}
#
# Key: https://www.nytimes.com/section/opinion/columnists
#  Value: {'link': 'https://www.nytimes.com/section/opinion/columnists', 'string': 'Op-Ed Columnists'}
#
# Key: https://www.nytimes.com/section/opinion/editorials
#  Value: {'link': 'https://www.nytimes.com/section/opinion/editorials', 'string': 'Editorials'}
#
# Key: https://www.nytimes.com/section/opinion/contributors
#  Value: {'link': 'https://www.nytimes.com/section/opinion/contributors', 'string': 'Op-Ed Contributors'}
#
# Key: https://www.nytimes.com/section/opinion/letters
#  Value: {'link': 'https://www.nytimes.com/section/opinion/letters', 'string': 'Letters'}
#
# Key: https://www.nytimes.com/section/opinion/sunday
#  Value: {'link': 'https://www.nytimes.com/section/opinion/sunday', 'string': 'Sunday Review'}
#
# Key: https://www.nytimes.com/video/opinion
#  Value: {'link': 'https://www.nytimes.com/video/opinion', 'string': 'Video: Opinion'}
#
# Key: https://www.nytimes.com/section/arts/design
#  Value: {'link': 'https://www.nytimes.com/section/arts/design', 'string': 'Art & Design'}
#
# Key: https://www.nytimes.com/section/arts/dance
#  Value: {'link': 'https://www.nytimes.com/section/arts/dance', 'string': 'Dance'}
#
# Key: https://www.nytimes.com/section/arts/music
#  Value: {'link': 'https://www.nytimes.com/section/arts/music', 'string': 'Music'}
#
# Key: https://www.nytimes.com/events/
#  Value: {'link': 'https://www.nytimes.com/events/', 'string': 'N.Y.C. Events Guide'}
#
# Key: https://www.nytimes.com/section/theater
#  Value: {'link': 'https://www.nytimes.com/section/theater', 'string': 'Theater'}
#
# Key: https://www.nytimes.com/video/arts
#  Value: {'link': 'https://www.nytimes.com/video/arts', 'string': 'Video: Arts'}
#
# Key: https://www.nytimes.com/section/automobiles
#  Value: {'link': 'https://www.nytimes.com/section/automobiles', 'string': 'Automobiles'}
#
# Key: https://www.nytimes.com/section/jobs
#  Value: {'link': 'https://www.nytimes.com/section/jobs', 'string': 'Jobs'}
#
# Key: https://www.nytimes.com/section/fashion/weddings
#  Value: {'link': 'https://www.nytimes.com/section/fashion/weddings', 'string': 'Weddings & Celebrations'}
#
# Key: https://www.nytimes.com/section/reader-center
#  Value: {'link': 'https://www.nytimes.com/section/reader-center', 'string': 'Reader Center'}
#
# Key: https://www.nytimes.com/ref/classifieds/
#  Value: {'link': 'https://www.nytimes.com/ref/classifieds/', 'string': 'Classifieds'}
#
# Key: https://www.nytimes.com/marketing/tools-and-services/
#  Value: {'link': 'https://www.nytimes.com/marketing/tools-and-services/', 'string': 'Tools & Services'}
#
# Key: https://www.nytimes.com/section/multimedia
#  Value: {'link': 'https://www.nytimes.com/section/multimedia', 'string': 'Multimedia'}
#
# Key: https://lens.blogs.nytimes.com/
#  Value: {'link': 'https://lens.blogs.nytimes.com/', 'string': 'Photography'}
#
# Key: https://store.nytimes.com/?action=click&contentCollection=NYT%20Store&contentPlacement=2&module=SectionsNav&pgtype=Homepage®ion=TopBar&t=qry542&utm_campaign=NYT-HP&utm_content=hp_browsetree&utm_medium=HPB&utm_source=nytimes&version=BrowseTree
#  Value: {'link': 'https://store.nytimes.com/?action=click&contentCollection=NYT%20Store&contentPlacement=2&module=SectionsNav&pgtype=Homepage®ion=TopBar&t=qry542&utm_campaign=NYT-HP&utm_content=hp_browsetree&utm_medium=HPB&utm_source=nytimes&version=BrowseTree', 'string': 'NYT Store'}
#
# Key: https://www.nytimes.com/times-journeys/?utm_source=nytimes&utm_medium=HPLink&utm_content=hp_browsetree&utm_campaign=NYT-HP
#  Value: {'link': 'https://www.nytimes.com/times-journeys/?utm_source=nytimes&utm_medium=HPLink&utm_content=hp_browsetree&utm_campaign=NYT-HP', 'string': 'Times Journeys'}
#
# Key: https://www.nytimes.com/seeallnav
#  Value: {'link': 'https://www.nytimes.com/seeallnav', 'string': 'Subscribe'}
#
# Key: https://www.nytimes.com/membercenter
#  Value: {'link': 'https://www.nytimes.com/membercenter', 'string': 'Manage My Account'}
#
# Key: http://www.nytco.com
#  Value: {'link': 'http://www.nytco.com', 'string': 'NYTCo'}
#
# Key: https://www.nytimes.com/hdleftnav
#  Value: {'link': 'https://www.nytimes.com/hdleftnav', 'string': 'Home Delivery'}
#
# Key: https://www.nytimes.com/digitalleftnav
#  Value: {'link': 'https://www.nytimes.com/digitalleftnav', 'string': 'Digital Subscriptions'}
#
# Key: https://www.nytimes.com/crosswords/index.html
#  Value: {'link': 'https://www.nytimes.com/crosswords/index.html', 'string': 'Crossword'}
#
# Key: https://www.nytimes.com/marketing/newsletters
#  Value: {'link': 'https://www.nytimes.com/marketing/newsletters', 'string': 'Email Newsletters'}
#
# Key: https://myaccount.nytimes.com/mem/tnt.html
#  Value: {'link': 'https://myaccount.nytimes.com/mem/tnt.html', 'string': 'Alerts'}
#
# Key: https://www.nytimes.com/giftleftnav
#  Value: {'link': 'https://www.nytimes.com/giftleftnav', 'string': 'Gift Subscriptions'}
#
# Key: https://www.nytimes.com/corporateleftnav
#  Value: {'link': 'https://www.nytimes.com/corporateleftnav', 'string': 'Corporate Subscriptions'}
#
# Key: https://www.nytimes.com/educationleftnav
#  Value: {'link': 'https://www.nytimes.com/educationleftnav', 'string': 'Education Rate'}
#
# Key: https://www.nytimes.com/services/mobile/index.html
#  Value: {'link': 'https://www.nytimes.com/services/mobile/index.html', 'string': 'Mobile Applications'}
#
# Key: http://eedition.nytimes.com/cgi-bin/signup.cgi?cc=37FYY
#  Value: {'link': 'http://eedition.nytimes.com/cgi-bin/signup.cgi?cc=37FYY', 'string': 'Replica Edition'}
#
# Key: https://www.nytimes.com/content/help/rights/copyright/copyright-notice.html
#  Value: {'link': 'https://www.nytimes.com/content/help/rights/copyright/copyright-notice.html', 'string': 'null'}
#
# Key: https://www.nytimes.com/ref/membercenter/help/infoservdirectory.html
#  Value: {'link': 'https://www.nytimes.com/ref/membercenter/help/infoservdirectory.html', 'string': 'Contact Us'}
#
# Key: http://www.nytco.com/careers
#  Value: {'link': 'http://www.nytco.com/careers', 'string': 'Work With Us'}
#
# Key: http://nytmediakit.com/
#  Value: {'link': 'http://nytmediakit.com/', 'string': 'Advertise'}
#
# Key: https://www.nytimes.com/content/help/rights/privacy/policy/privacy-policy.html#pp
#  Value: {'link': 'https://www.nytimes.com/content/help/rights/privacy/policy/privacy-policy.html#pp', 'string': 'Your Ad Choices'}
#
# Key: https://www.nytimes.com/privacy
#  Value: {'link': 'https://www.nytimes.com/privacy', 'string': 'Privacy'}
#
# Key: https://www.nytimes.com/ref/membercenter/help/agree.html
#  Value: {'link': 'https://www.nytimes.com/ref/membercenter/help/agree.html', 'string': 'Terms of Service'}
#
# Key: https://www.nytimes.com/content/help/rights/sale/terms-of-sale.html
#  Value: {'link': 'https://www.nytimes.com/content/help/rights/sale/terms-of-sale.html', 'string': 'Terms of Sale'}
#
# Key: http://spiderbites.nytimes.com
#  Value: {'link': 'http://spiderbites.nytimes.com', 'string': 'Site Map'}
#
# Key: https://www.nytimes.com/membercenter/sitehelp.html
#  Value: {'link': 'https://www.nytimes.com/membercenter/sitehelp.html', 'string': 'Help'}
#
# Key: https://myaccount.nytimes.com/membercenter/feedback.html
#  Value: {'link': 'https://myaccount.nytimes.com/membercenter/feedback.html', 'string': 'Site Feedback'}
#
# Key: https://www.nytimes.com/subscriptions/Multiproduct/lp5558.html?campaignId=37WXW
#  Value: {'link': 'https://www.nytimes.com/subscriptions/Multiproduct/lp5558.html?campaignId=37WXW', 'string': 'Subscriptions'}
#
# Key: https://mobile.nytimes.com/
#  Value: {'link': 'https://mobile.nytimes.com/', 'string': 'View Mobile Version'}

# %% [markdown]
# As you can see each entry has 3 fields. 'link','string', and 'title' with the key being the link.

# %% [markdown]
# ### Writing to a csv file
#
# Now that we have all the information we need, it is time to write it into a csv file

# %%
#Open a csv file to save it into (if it doesn't exist it will create one)
outputfile = open( 'webPageLink.csv', 'w' )

#Iterate through the created dictionary and create an entry for each
for key, nestDictionary in  linkDictionary.items() :
    #The first feild would be the 'href' value
    outputfile.write( str(key))
    #For each element in the nested list add it
    for value in nestDictionary.values():
        outputfile.write("," + str(value))
    #End the entry
    outputfile.write("\n")

#Close the file
outputfile.close()

# %% [markdown]
# ## Completition
#
# Now you have parsed a website for all the URL redirects on the page and saved all the relavent links, meta data, etc into a csv file. Although in the csv file there is some unnecessary content (in this example, there are some link that take you down to the reference section on the bottom of the web page), every outgoing URL link is now saved.
